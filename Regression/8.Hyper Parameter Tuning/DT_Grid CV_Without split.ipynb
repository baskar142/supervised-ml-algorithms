# %%
#importing numpy libarary, It provides support for large, multi-dimensional arrays and matrices
import numpy as np
#importing numpy libarary, It provides support for data manipulation and analysis. 
import pandas as pd
# importing matplotlib.pyplot plotting library in Python that provides a MATLAB-like interface for creating visualizations. 
import matplotlib.pyplot as plt

# %%
#Reading the csv file using pandas function and saved in data variable
data = pd.read_csv("insurance_pre.csv")

# %%
data = pd.get_dummies(data, drop_first=True)#1st column is dropped, CA is dropped
data.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dependent =data[["charges"]]

independent =data[["age","bmi", "children", "sex_male","smoker_yes"]]

# %%
#importing train_test_split from sklearn.model_selection which is used for splitting the data into train and test
#from sklearn.model_selection import train_test_split

#splitting Xtrain,X_test, y_train and y_test usiing train_test_split function. Train and test split ratio is 70% and 30% respectively
#X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc =StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV


param_grid =  {'criterion':['mse', 'mae', 'friedman_mse'], 'max_features':['auto','sqrt','log2'], 'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#grid.fit(X_train,y_train)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\AB92922\anaconda3\lib\site-packages\sklearn\tree\_classes.py:366: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'mae', 'max_features': 'auto', 'splitter': 'best'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016523      0.003151         0.005614        0.001305
# 1        0.013049      0.003774         0.006037        0.001094
# 2        0.010922      0.003083         0.005686        0.001762
# 3        0.010148      0.001399         0.005200        0.000642
# 4        0.010583      0.002210         0.004425        0.000790
# 5        0.008942      0.002701         0.004836        0.000945
# 6        0.045497      0.003634         0.004597        0.001067
# 7        0.036046      0.004152         0.004512        0.000829
# 8        0.030316      0.003562         0.004105        0.000327
# 9        0.023446      0.001222         0.004106        0.000896
# 10       0.032922      0.002994         0.004040        0.000784
# 11       0.023450      0.001926         0.004252        0.000439
# 12       0.010357      0.002566         0.004025        0.000052
# 13       0.007397      0.000489         0.004610        0.000814
# 14       0.008242      0.001210         0.004852        0.000991
# 15       0.006272      0.000368         0.004072        0.000053
# 16       0.007911      0.001014         0.004213        0.000269
# 17       0.006935      0.000708         0.003808        0.000576
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.728149
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.746831
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.601414
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.639613
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.701096
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.671535
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.730964
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.693903
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.705144
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.701922
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.719943
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.725244
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.715708
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.653955
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.716489
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.637203
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.727127
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.660695
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.646307           0.726433           0.692039
# 1            0.588871           0.702685           0.691448
# 2            0.567010           0.718662           0.721087
# 3            0.502928           0.668605           0.680238
# 4            0.698736           0.712311           0.721286
# 5            0.617243           0.729913           0.711163
# 6            0.615744           0.754697           0.737012
# 7            0.596128           0.642655           0.711642
# 8            0.470238           0.639583           0.779824
# 9            0.643788           0.679734           0.721890
# 10           0.490907           0.725827           0.555275
# 11           0.516443           0.745637           0.702864
# 12           0.655894           0.727980           0.700614
# 13           0.641240           0.697240           0.718742
# 14           0.614408           0.699319           0.700379
# 15           0.328848           0.701759           0.668296
# 16           0.647654           0.719256           0.718651
# 17           0.574502           0.696387           0.724969
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.690501         0.696686        0.029909                4
# 1            0.757248         0.697416        0.059778                3
# 2            0.743272         0.670289        0.071634               11
# 3            0.576675         0.613612        0.065961               17
# 4            0.692665         0.705219        0.010248                2
# 5            0.714552         0.688881        0.040674                6
# 6            0.752179         0.718119        0.051963                1
# 7            0.749498         0.678765        0.053751                8
# 8            0.707815         0.660521        0.104983               15
# 9            0.662696         0.682006        0.027662                7
# 10           0.687544         0.635899        0.095227               16
# 11           0.626712         0.663380        0.083770               13
# 12           0.673960         0.694831        0.026532                5
# 13           0.667902         0.675816        0.028417               10
# 14           0.655374         0.677194        0.037388                9
# 15           0.683449         0.603911        0.139150               18
# 16           0.530868         0.668711        0.074706               12
# 17           0.659480         0.663207        0.050605               14

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
childern_input = float(input("childern:"))
sex_male_input = float(input("Sex Male 0 or 1:"))
smoker_yes_input = float(input("Smoker yes 0 or 1:"))
# Out:
# Age:44
# BMI:33
# childern:1
# Sex Male 0 or 1:1
# Smoker yes 0 or 1:1

# %%
Future_prediction = grid.predict([[age_input, bmi_input, childern_input, sex_male_input, smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[41919.097]
# C:\Users\AB92922\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
#model saved in save fomat
filename = 'DTmodel_WithoutTrainSplit.sav'
#pickle.dump() serializes the regressor object and writes it to the specified file (filename) in binary mode ('wb').
pickle.dump(grid, open(filename, 'wb'))

# %%
# the mode 'rb' used in file operations stands for "read binary" and saved in laoded model
loaded_model = pickle.load(open('DTmodel_WithoutTrainSplit.sav','rb'))
#using predict keyeword, predicting 15 years of experience of emplyee and predicted value store in result variable
result = loaded_model.predict([[55,32,1,1,0]])
#pring the result
print(result)
# Out:
# [10807.4863]
# C:\Users\AB92922\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
