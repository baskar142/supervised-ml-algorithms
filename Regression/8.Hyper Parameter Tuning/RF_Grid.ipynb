# %%
#importing numpy libarary, It provides support for large, multi-dimensional arrays and matrices
import numpy as np
#importing numpy libarary, It provides support for data manipulation and analysis. 
import pandas as pd
# importing matplotlib.pyplot plotting library in Python that provides a MATLAB-like interface for creating visualizations. 
import matplotlib.pyplot as plt

# %%
#Reading the csv file using pandas function and saved in data variable
data = pd.read_csv("insurance_pre.csv")

# %%
data = pd.get_dummies(data, drop_first=True)#1st column is dropped, CA is dropped
data.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dependent =data[["charges"]]

independent =data[["age","bmi", "children", "sex_male","smoker_yes"]]

# %%
#importing train_test_split from sklearn.model_selection which is used for splitting the data into train and test
from sklearn.model_selection import train_test_split

#splitting Xtrain,X_test, y_train and y_test usiing train_test_split function. Train and test split ratio is 70% and 30% respectively
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV


param_grid =  {'criterion':['mse', 'mae'], 'max_features':['auto','sqrt','log2'], 'n_estimators':[10,100]}

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\AB92922\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\AB92922\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'mse', 'max_features': 'log2', 'n_estimators': 100}:

# %%
grid_predictions = grid.predict(X_test)
from sklearn.metrics import r2_score
r_score= r2_score(y_test,grid_predictions)
r_score
# Out:
# 0.8706914220412344

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.106502      0.015483         0.010001        0.004603
# 1        0.776094      0.011712         0.040621        0.001305
# 2        0.079478      0.008186         0.009599        0.001355
# 3        0.647745      0.020864         0.041648        0.002028
# 4        0.072567      0.002780         0.008803        0.000978
# 5        0.673046      0.055311         0.042254        0.001574
# 6        0.329120      0.010692         0.008080        0.000512
# 7        3.246121      0.320408         0.043395        0.011978
# 8        0.243540      0.029709         0.009085        0.003494
# 9        2.158128      0.123577         0.038145        0.004854
# 10       0.260439      0.047756         0.009208        0.001290
# 11       1.982635      0.032199         0.036576        0.006682
#
#    param_criterion param_max_features param_n_estimators  \
# 0              mse               auto                 10
# 1              mse               auto                100
# 2              mse               sqrt                 10
# 3              mse               sqrt                100
# 4              mse               log2                 10
# 5              mse               log2                100
# 6              mae               auto                 10
# 7              mae               auto                100
# 8              mae               sqrt                 10
# 9              mae               sqrt                100
# 10             mae               log2                 10
# 11             mae               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.849787
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.860205
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.846991
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.870621
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.850491
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.864573
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.821445
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.851085
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.829381
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.858547
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.820562
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.856861
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.716892           0.799015           0.781760
# 1            0.767713           0.812816           0.801644
# 2            0.759554           0.790901           0.797676
# 3            0.794590           0.802457           0.823246
# 4            0.769329           0.774791           0.790971
# 5            0.790721           0.815574           0.831328
# 6            0.769131           0.776961           0.793976
# 7            0.773357           0.795534           0.802288
# 8            0.754781           0.813367           0.809008
# 9            0.794936           0.807799           0.820277
# 10           0.774896           0.798342           0.812537
# 11           0.788898           0.807518           0.826513
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.761981         0.781887        0.043645               12
# 1            0.769545         0.802385        0.033862                5
# 2            0.768115         0.792647        0.030589                8
# 3            0.767488         0.811681        0.034461                2
# 4            0.753894         0.787895        0.033467                9
# 5            0.766756         0.813790        0.033568                1
# 6            0.760536         0.784410        0.021550               11
# 7            0.764445         0.797342        0.030244                7
# 8            0.720102         0.785328        0.041171               10
# 9            0.773294         0.810970        0.028414                3
# 10           0.780941         0.797456        0.017571                6
# 11           0.766124         0.809183        0.031119                4

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
childern_input = float(input("childern:"))
sex_male_input = float(input("Sex Male 0 or 1:"))
smoker_yes_input = float(input("Smoker yes 0 or 1:"))
# Out:
# Age:55
# BMI:33
# childern:1
# Sex Male 0 or 1:1
# Smoker yes 0 or 1:1

# %%
Future_prediction = grid.predict([[age_input, bmi_input, childern_input, sex_male_input, smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[48229.4360954]
