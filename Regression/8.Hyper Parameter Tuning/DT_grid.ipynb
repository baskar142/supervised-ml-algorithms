# %%
#importing numpy libarary, It provides support for large, multi-dimensional arrays and matrices
import numpy as np
#importing numpy libarary, It provides support for data manipulation and analysis. 
import pandas as pd
# importing matplotlib.pyplot plotting library in Python that provides a MATLAB-like interface for creating visualizations. 
import matplotlib.pyplot as plt

# %%
#Reading the csv file using pandas function and saved in data variable
data = pd.read_csv("insurance_pre.csv")

# %%
data = pd.get_dummies(data, drop_first=True)#1st column is dropped, CA is dropped
data.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dependent =data[["charges"]]

independent =data[["age","bmi", "children", "sex_male","smoker_yes"]]

# %%
#importing train_test_split from sklearn.model_selection which is used for splitting the data into train and test
from sklearn.model_selection import train_test_split

#splitting Xtrain,X_test, y_train and y_test usiing train_test_split function. Train and test split ratio is 70% and 30% respectively
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid =  {'criterion':['mse', 'mae', 'friedman_mse'], 'max_features':['auto','sqrt','log2'], 'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\AB92922\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'mse', 'max_features': 'auto', 'splitter': 'best'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018219      0.002330         0.004924        0.000133
# 1        0.010927      0.002593         0.004948        0.000530
# 2        0.010083      0.000774         0.005574        0.001143
# 3        0.007943      0.001065         0.003848        0.000766
# 4        0.009416      0.001560         0.004195        0.000497
# 5        0.010757      0.002425         0.008080        0.002760
# 6        0.062314      0.004056         0.004419        0.000481
# 7        0.046487      0.002474         0.004509        0.000640
# 8        0.037099      0.003269         0.004276        0.000392
# 9        0.029006      0.002848         0.004806        0.000748
# 10       0.035394      0.003585         0.004207        0.000976
# 11       0.027731      0.009820         0.003922        0.000474
# 12       0.011299      0.000847         0.004397        0.000489
# 13       0.008689      0.000779         0.004702        0.000604
# 14       0.008248      0.000498         0.005303        0.001885
# 15       0.008828      0.002829         0.004072        0.000639
# 16       0.008839      0.000430         0.004400        0.000801
# 17       0.007223      0.001338         0.003782        0.000680
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.728650
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.673391
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.429017
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.715937
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.604499
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.594215
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.745357
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.618405
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.658183
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.663233
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.672130
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.651487
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.742083
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.696810
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.702488
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.778920
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.741970
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.521392
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.548645           0.761706           0.644795
# 1            0.692550           0.683189           0.610239
# 2            0.667630           0.695682           0.657624
# 3            0.572606           0.605565           0.581683
# 4            0.612405           0.552037           0.542519
# 5            0.663944           0.513804           0.612590
# 6            0.613629           0.608613           0.532568
# 7            0.658751           0.711082           0.639455
# 8            0.674149           0.647147           0.516408
# 9            0.574459           0.573609           0.383463
# 10           0.647449           0.698837           0.498652
# 11           0.604468           0.753979           0.489451
# 12           0.529255           0.764336           0.644970
# 13           0.686654           0.673874           0.640249
# 14           0.288151           0.349044           0.574820
# 15           0.507518           0.574229           0.387342
# 16           0.654829           0.733830           0.545036
# 17           0.467962           0.365921           0.580020
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.679666         0.672692        0.073850                1
# 1            0.586230         0.649120        0.042668                5
# 2            0.506786         0.591348        0.104498               13
# 3            0.596813         0.614521        0.051989               11
# 4            0.613946         0.585081        0.031178               14
# 5            0.650426         0.606996        0.052931               12
# 6            0.662794         0.632592        0.070096                7
# 7            0.688213         0.663181        0.033192                4
# 8            0.607077         0.620593        0.056610                9
# 9            0.560121         0.550977        0.091444               16
# 10           0.609323         0.625278        0.069837                8
# 11           0.599477         0.619772        0.085612               10
# 12           0.673028         0.670734        0.083111                2
# 13           0.631811         0.665880        0.025573                3
# 14           0.521231         0.487147        0.150925               18
# 15           0.585991         0.566800        0.127387               15
# 16           0.515976         0.638328        0.093603                6
# 17           0.576163         0.502292        0.079548               17

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
childern_input = float(input("childern:"))
sex_male_input = float(input("Sex Male 0 or 1:"))
smoker_yes_input = float(input("Smoker yes 0 or 1:"))
# Out:
# Age:33
# BMI:22
# childern:1
# Sex Male 0 or 1:1
# Smoker yes 0 or 1:1

# %%
Future_prediction = grid.predict([[age_input, bmi_input, childern_input, sex_male_input, smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[63770.42801]
